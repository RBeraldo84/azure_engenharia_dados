# %% [markdown]
# # Tabelas Dados Externos Work

# %% [markdown]
# ## Imports

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %% [markdown]
# ## Análise Inicial

# %%
dados_externos = spark.sql("SELECT * FROM raw.dados_externos_raw LIMIT 100")
dados_externos.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## Seleção das Bases

# %%
dados_externos = dados_externos.withColumnRenamed('codigo_loja', 'cod_loja') \
    .withColumnRenamed('domicliosportipo', 'domicilios_por_tipo')

# %% [markdown]
# ### Densidade Demográfica por Renda

# %% [markdown]
# #### Colunas

# %%
colunas_dados_externos_densidade_demografica_por_renda_work = ['cod_loja',
 'area',
 'populacao',
 'dens_demografica',
 'domicilios',
 'renda_media',
 'renda_nominal',
 'pea_dia',
 'populacao_trabalha']

# %%
dados_externos_densidade_demografica_por_renda_work = dados_externos[colunas_dados_externos_densidade_demografica_por_renda_work]
dados_externos_densidade_demografica_por_renda_work.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #### Casting

# %%
dados_externos_densidade_demografica_por_renda_work = dados_externos_densidade_demografica_por_renda_work.withColumn('cod_loja', regexp_replace('cod_loja', ',', '.').cast(IntegerType())) \
    .withColumn('area', regexp_replace('area', ',', '.').cast(DoubleType())) \
    .withColumn('populacao', regexp_replace('populacao', ',', '.').cast(DoubleType())) \
    .withColumn('dens_demografica', regexp_replace('dens_demografica', ',', '.').cast(DoubleType())) \
    .withColumn('domicilios', regexp_replace('domicilios', ',', '.').cast(DoubleType())) \
    .withColumn('renda_media', regexp_replace('renda_media', ',', '.').cast(DoubleType())) \
    .withColumn('renda_nominal', regexp_replace('renda_nominal', ',', '.').cast(DoubleType())) \
    .withColumn('pea_dia', regexp_replace('pea_dia', ',', '.').cast(IntegerType())) \
    .withColumn('populacao_trabalha', regexp_replace('populacao_trabalha', ',', '.').cast(IntegerType()))

# %%
dados_externos_densidade_demografica_por_renda_work.write \
    .partitionBy(['cod_loja']) \
    .mode('overwrite') \
    .saveAsTable('dev.dados_externos_densidade_demografica_por_renda_dev')

# %% [markdown]
# #### Otimizando

# %%
# %sql
OPTIMIZE dev.dados_externos_densidade_demografica_por_renda_dev
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/mnt/dev/dados_externos_densidade_demografica_por_renda_dev</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 100, null, 0, 100, 100, true, 0, 0, 1679974879977, 1679974882688, 8, 0, null)</td></tr></tbody></table></div>

# %% [markdown]
# ### Domicilios por Faixa de Renda

# %% [markdown]
# #### Colunas

# %%
colunas_dados_externos_domicilios_por_faixa_de_renda = ['cod_loja',
 'dom_f_renda_a2mais_40mais',
 'dom_f_renda_a2mais_34a40',
 'dom_f_renda_a2mais_30a34',
 'dom_f_renda_a2mais_28a30',
 'dom_f_renda_a2mais',
 'dom_f_renda_amais_21a28',
 'dom_f_renda_amais_16a21',
 'dom_f_renda_amais',
 'dom_f_renda_b1_13a16',
 'dom_f_renda_b1_11a13',
 'dom_f_renda_b1_8a11',
 'dom_f_renda_b1',
 'dom_f_renda_b2_5a8',
 'dom_f_renda_4a5',
 'dom_f_renda_b2',
 'dom_f_renda_c1_2a4',
 'dom_f_renda_c1',
 'dom_f_renda_c2_1a2',
 'dom_f_renda_c2',
 'dom_f_renda_d_1a1',
 'dom_f_renda_d',
 'dom_f_renda_e_ate1',
 'dom_f_renda_e']

# %%
dados_externos_domicilios_por_faixa_de_renda = dados_externos[colunas_dados_externos_domicilios_por_faixa_de_renda]
dados_externos_domicilios_por_faixa_de_renda.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #### Casting

# %%
['cod_loja',
 'dom_f_renda_a2mais_40mais',
 'dom_f_renda_a2mais_34a40',
 'dom_f_renda_a2mais_30a34',
 'dom_f_renda_a2mais_28a30',
 'dom_f_renda_a2mais',
 'dom_f_renda_amais_21a28',
 'dom_f_renda_amais_16a21',
 'dom_f_renda_amais',
 'dom_f_renda_b1_13a16',
 'dom_f_renda_b1_11a13',
 'dom_f_renda_b1_8a11',
 'dom_f_renda_b1',
 'dom_f_renda_b2_5a8',
 'dom_f_renda_4a5',
 'dom_f_renda_b2',
 'dom_f_renda_c1_2a4',
 'dom_f_renda_c1',
 'dom_f_renda_c2_1a2',
 'dom_f_renda_c2',
 'dom_f_renda_d_1a1',
 'dom_f_renda_d',
 'dom_f_renda_e_ate1',
 'dom_f_renda_e']

# %%
dados_externos_domicilios_por_faixa_de_renda = dados_externos_domicilios_por_faixa_de_renda.withColumn('cod_loja', regexp_replace('cod_loja', ',', '.').cast(IntegerType())) \
    .withColumn('dom_f_renda_a2mais_40mais', regexp_replace('dom_f_renda_a2mais_40mais', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_a2mais_34a40', regexp_replace('dom_f_renda_a2mais_34a40', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_a2mais_30a34', regexp_replace('dom_f_renda_a2mais_30a34', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_a2mais_28a30', regexp_replace('dom_f_renda_a2mais_28a30', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_a2mais', regexp_replace('dom_f_renda_a2mais', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_amais_21a28', regexp_replace('dom_f_renda_amais_21a28', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_amais_16a21', regexp_replace('dom_f_renda_amais_16a21', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_amais', regexp_replace('dom_f_renda_amais', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_b1_13a16', regexp_replace('dom_f_renda_b1_13a16', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_b1_11a13', regexp_replace('dom_f_renda_b1_11a13', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_b1_8a11', regexp_replace('dom_f_renda_b1_8a11', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_b1', regexp_replace('dom_f_renda_b1', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_b2_5a8', regexp_replace('dom_f_renda_b2_5a8', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_4a5', regexp_replace('dom_f_renda_4a5', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_b2', regexp_replace('dom_f_renda_b2', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_c1_2a4', regexp_replace('dom_f_renda_c1_2a4', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_c1', regexp_replace('dom_f_renda_c1', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_c2_1a2', regexp_replace('dom_f_renda_c2_1a2', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_c2', regexp_replace('dom_f_renda_c2', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_d_1a1', regexp_replace('dom_f_renda_d_1a1', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_d', regexp_replace('dom_f_renda_d', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_e_ate1', regexp_replace('dom_f_renda_e_ate1', ',', '.').cast(DoubleType())) \
    .withColumn('dom_f_renda_e', regexp_replace('dom_f_renda_e', ',', '.').cast(DoubleType()))

# %%
dados_externos_domicilios_por_faixa_de_renda.write \
    .partitionBy(['cod_loja']) \
    .mode('overwrite') \
    .saveAsTable('dev.dados_externos_domicilios_por_faixa_de_renda_dev')

# %%
# %sql
OPTIMIZE dev.dados_externos_domicilios_por_faixa_de_renda_dev
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/mnt/dev/dados_externos_domicilios_por_faixa_de_renda_dev</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 100, null, 0, 100, 100, true, 0, 0, 1679975770304, 1679975771334, 8, 0, null)</td></tr></tbody></table></div>

# %% [markdown]
# ### Renda Nominal Work

# %% [markdown]
# #### Colunas

# %%
colunas_dados_externos_renda_nominal_work = ['cod_loja',
 'renda_nominal_f_a2mais',
 'renda_nominal_f_a',
 'renda_nominal_f_b1',
 'renda_nominal_f_b2',
 'renda_nominal_f_c1',
 'renda_nominal_f_c2',
 'renda_nominal_f_d',
 'renda_nominal_f_e']

# %%
dados_externos_renda_nominal_work = dados_externos[colunas_dados_externos_renda_nominal_work]
dados_externos_renda_nominal_work.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #### Casting

# %%
dados_externos_renda_nominal_work = dados_externos_renda_nominal_work.withColumn('cod_loja', regexp_replace('cod_loja', ',', '.').cast(IntegerType())) \
    .withColumn('renda_nominal_f_a2mais', regexp_replace('renda_nominal_f_a2mais', ',', '.').cast(DoubleType())) \
    .withColumn('renda_nominal_f_a', regexp_replace('renda_nominal_f_a', ',', '.').cast(DoubleType())) \
    .withColumn('renda_nominal_f_b1', regexp_replace('renda_nominal_f_b1', ',', '.').cast(DoubleType())) \
    .withColumn('renda_nominal_f_b2', regexp_replace('renda_nominal_f_b2', ',', '.').cast(DoubleType())) \
    .withColumn('renda_nominal_f_c1', regexp_replace('renda_nominal_f_c1', ',', '.').cast(DoubleType())) \
    .withColumn('renda_nominal_f_c2', regexp_replace('renda_nominal_f_c2', ',', '.').cast(DoubleType())) \
    .withColumn('renda_nominal_f_d', regexp_replace('renda_nominal_f_d', ',', '.').cast(DoubleType())) \
    .withColumn('renda_nominal_f_e', regexp_replace('renda_nominal_f_e', ',', '.').cast(DoubleType()))

# %% [markdown]
# #### Salvando

# %%
dados_externos_renda_nominal_work.write \
    .partitionBy(['cod_loja']) \
    .mode('overwrite') \
    .saveAsTable('dev.dados_externos_renda_nominal_dev')

# %%
# %sql
OPTIMIZE dev.dados_externos_renda_nominal_dev
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/mnt/dev/dados_externos_renda_nominal_dev</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 100, null, 0, 100, 100, true, 0, 0, 1679982941487, 1679982942196, 8, 0, null)</td></tr></tbody></table></div>

# %% [markdown]
# ### Faixa Etária População Work

# %% [markdown]
# #### Colunas

# %%
 colunas_dados_externos_faixa_etaria_populacao_work = ['cod_loja',
 'pop_f_etaria_ate4',
 'pop_f_etaria_5a9',
 'pop_f_etaria_ate9',
 'pop_f_etaria_10a14',
 'pop_f_etaria_15a19',
 'pop_f_etaria_20a24',
 'pop_f_etaria_25a29',
 'pop_f_etaria_30a34',
 'pop_f_etaria_25a34',
 'pop_f_etaria_35a39',
 'pop_f_etaria_40a44',
 'pop_f_etaria_45a49',
 'pop_f_etaria_35a49',
 'pop_f_etaria_50a54',
 'pop_f_etaria_55a59',
 'pop_f_etaria_50a59',
 'pop_f_etaria_60a64',
 'pop_f_etaria_65a69',
 'pop_f_etaria_70a74',
 'pop_f_etaria_75a79',
 'pop_f_etaria_80mais',
 'pop_f_etaria_60mais',
 'pop_homem',
 'pop_mulher']

# %%
dados_externos_faixa_etaria_populacao_work = dados_externos[colunas_dados_externos_faixa_etaria_populacao_work]
dados_externos_faixa_etaria_populacao_work.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #### Casting

# %%
dados_externos_faixa_etaria_populacao_work = dados_externos_faixa_etaria_populacao_work.withColumn('cod_loja', regexp_replace('cod_loja', ',', '.').cast(IntegerType())) \
    .withColumn('pop_f_etaria_ate4', regexp_replace('pop_f_etaria_ate4', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_5a9', regexp_replace('pop_f_etaria_5a9', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_ate9', regexp_replace('pop_f_etaria_ate9', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_10a14', regexp_replace('pop_f_etaria_10a14', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_15a19', regexp_replace('pop_f_etaria_15a19', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_20a24', regexp_replace('pop_f_etaria_20a24', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_25a29', regexp_replace('pop_f_etaria_25a29', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_30a34', regexp_replace('pop_f_etaria_30a34', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_25a34', regexp_replace('pop_f_etaria_25a34', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_35a39', regexp_replace('pop_f_etaria_35a39', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_40a44', regexp_replace('pop_f_etaria_40a44', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_45a49', regexp_replace('pop_f_etaria_45a49', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_35a49', regexp_replace('pop_f_etaria_35a49', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_50a54', regexp_replace('pop_f_etaria_50a54', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_55a59', regexp_replace('pop_f_etaria_55a59', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_50a59', regexp_replace('pop_f_etaria_50a59', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_60a64', regexp_replace('pop_f_etaria_60a64', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_65a69', regexp_replace('pop_f_etaria_65a69', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_70a74', regexp_replace('pop_f_etaria_70a74', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_75a79', regexp_replace('pop_f_etaria_75a79', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_80mais', regexp_replace('pop_f_etaria_80mais', ',', '.').cast(DoubleType())) \
    .withColumn('pop_f_etaria_60mais', regexp_replace('pop_f_etaria_60mais', ',', '.').cast(DoubleType())) \
    .withColumn('pop_homem', regexp_replace('pop_homem', ',', '.').cast(DoubleType())) \
    .withColumn('pop_mulher', regexp_replace('pop_mulher', ',', '.').cast(DoubleType()))

# %% [markdown]
# #### Salvando Dados

# %%
dados_externos_faixa_etaria_populacao_work.write \
    .partitionBy(['cod_loja']) \
    .mode('overwrite') \
    .saveAsTable('dev.dados_externos_faixa_etaria_populacao_dev')

# %%
# %sql
OPTIMIZE dev.dados_externos_faixa_etaria_populacao_devdados_externos_faixa_etaria_populacao_work
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/mnt/dev/dados_externos_faixa_etaria_populacao_dev</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 100, null, 0, 100, 100, true, 0, 0, 1679979453882, 1679979454761, 8, 0, null)</td></tr></tbody></table></div>

# %% [markdown]
# ### Instrução por Domicílio

# %% [markdown]
# #### Colunas

# %%
 colunas_dados_externos_instrucao_por_domicilio = ['cod_loja',
 'instru_sem_inst_ou_fund_incompleto',
 'instru_fund_completo_med_incompleto',
 'instru_med_completo_sup_incompleto',
 'instru_sup_completo',
 'instru_n_determinado']

# %%
dados_externos_instrucao_por_domicilio = dados_externos[colunas_dados_externos_instrucao_por_domicilio]
dados_externos_instrucao_por_domicilio.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #### Casting

# %%
dados_externos_instrucao_por_domicilio = dados_externos_instrucao_por_domicilio.withColumn('cod_loja', regexp_replace('cod_loja', ',', '.').cast(IntegerType())) \
    .withColumn('instru_sem_inst_ou_fund_incompleto', regexp_replace('instru_sem_inst_ou_fund_incompleto', ',', '.').cast(DoubleType())) \
    .withColumn('instru_fund_completo_med_incompleto', regexp_replace('instru_fund_completo_med_incompleto', ',', '.').cast(DoubleType())) \
    .withColumn('instru_med_completo_sup_incompleto', regexp_replace('instru_med_completo_sup_incompleto', ',', '.').cast(DoubleType())) \
    .withColumn('instru_sup_completo', regexp_replace('instru_sup_completo', ',', '.').cast(DoubleType())) \
    .withColumn('instru_n_determinado', regexp_replace('instru_n_determinado', ',', '.').cast(DoubleType()))

# %% [markdown]
# #### Salvando

# %%
dados_externos_instrucao_por_domicilio.write \
    .partitionBy(['cod_loja']) \
    .mode('overwrite') \
    .saveAsTable('dev.dados_externos_instrucao_por_domicilio_dev')

# %%
# %sql
OPTIMIZE dev.dados_externos_instrucao_por_domicilio_dev
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/mnt/dev/dados_externos_instrucao_por_domicilio_dev</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 100, null, 0, 100, 100, true, 0, 0, 1679977146904, 1679977147732, 8, 0, null)</td></tr></tbody></table></div>

# %% [markdown]
# ### Tipo Domicilio Work

# %% [markdown]
# #### Colunas

# %%
colunas_dados_externos_tipo_domicilio_work = ['cod_loja',
 'domicilios_t_casa',
 'domicilios_t_vila_condomnio',
 'domicilios_t_apartamento',
 'domicilios_t_outrotipo',
 'domicilios_c_ocupa_proprio_aquis',
 'domicilios_c_ocupa_proprio_quitado',
 'domicilios_c_ocupa_proprio',
 'domicilios_c_ocupa_alugado',
 'domicilios_c_ocupa_ced_empregador',
 'domicilios_c_ocupa_ced_outros',
 'domicilios_c_ocupa_ced',
 'domicilios_c_ocupa_outros',
 'dom_n_moradores_1',
 'dom_n_moradores_2',
 'dom_n_moradores_3',
 'dom_n_moradores_4',
 'dom_n_moradores_5mais',
 'domicilios_por_tipo']

# %%
dados_externos_tipo_domicilio_work = dados_externos[colunas_dados_externos_tipo_domicilio_work]
dados_externos_tipo_domicilio_work.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #### Casting

# %%
dados_externos_tipo_domicilio_work = dados_externos_tipo_domicilio_work.withColumn('cod_loja', regexp_replace('cod_loja', ',', '.').cast(IntegerType())) \
    .withColumn('domicilios_t_casa', regexp_replace('domicilios_t_casa', ',', '.').cast(IntegerType())) \
    .withColumn('domicilios_t_vila_condomnio', regexp_replace('domicilios_t_vila_condomnio', ',', '.').cast(IntegerType())) \
    .withColumn('domicilios_t_apartamento', regexp_replace('domicilios_t_apartamento', ',', '.').cast(IntegerType())) \
    .withColumn('domicilios_t_outrotipo', regexp_replace('domicilios_t_outrotipo', ',', '.').cast(IntegerType())) \
    .withColumn('domicilios_c_ocupa_proprio_aquis', regexp_replace('domicilios_c_ocupa_proprio_aquis', ',', '.').cast(IntegerType())) \
    .withColumn('domicilios_c_ocupa_proprio_quitado', regexp_replace('domicilios_c_ocupa_proprio_quitado', ',', '.').cast(IntegerType())) \
    .withColumn('domicilios_c_ocupa_proprio', regexp_replace('domicilios_c_ocupa_proprio', ',', '.').cast(IntegerType())) \
    .withColumn('domicilios_c_ocupa_alugado', regexp_replace('domicilios_c_ocupa_alugado', ',', '.').cast(IntegerType())) \
    .withColumn('domicilios_c_ocupa_ced_empregador', regexp_replace('domicilios_c_ocupa_ced_empregador', ',', '.').cast(IntegerType())) \
    .withColumn('domicilios_c_ocupa_ced_outros', regexp_replace('domicilios_c_ocupa_ced_outros', ',', '.').cast(IntegerType())) \
    .withColumn('domicilios_c_ocupa_ced', regexp_replace('domicilios_c_ocupa_ced', ',', '.').cast(IntegerType())) \
    .withColumn('domicilios_c_ocupa_outros', regexp_replace('domicilios_c_ocupa_outros', ',', '.').cast(IntegerType())) \
    .withColumn('dom_n_moradores_1', regexp_replace('dom_n_moradores_1', ',', '.').cast(IntegerType())) \
    .withColumn('dom_n_moradores_2', regexp_replace('dom_n_moradores_2', ',', '.').cast(IntegerType())) \
    .withColumn('dom_n_moradores_3', regexp_replace('dom_n_moradores_3', ',', '.').cast(IntegerType())) \
    .withColumn('dom_n_moradores_4', regexp_replace('dom_n_moradores_4', ',', '.').cast(IntegerType())) \
    .withColumn('dom_n_moradores_5mais', regexp_replace('dom_n_moradores_5mais', ',', '.').cast(IntegerType())) \
    .withColumn('domicilios_por_tipo', regexp_replace('domicilios_por_tipo', ',', '.').cast(IntegerType()))

# %% [markdown]
# #### Salvando

# %%
dados_externos_tipo_domicilio_work.write \
    .partitionBy(['cod_loja']) \
    .mode('overwrite') \
    .saveAsTable('dev.dados_externos_tipo_domicilio_dev')

# %%
# %sql
OPTIMIZE dev.dados_externos_tipo_domicilio_dev
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/mnt/dev/dados_externos_tipo_domicilio_dev</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 100, null, 0, 100, 100, true, 0, 0, 1679977572556, 1679977573255, 8, 0, null)</td></tr></tbody></table></div>

# %% [markdown]
# ### Populacao Economicamente Ativa Work

# %% [markdown]
# #### Colunas

# %%
colunas_dados_externos_populacao_economicamente_ativa_work = ['cod_loja',
 'f_pea_dia_20mais',
 'f_pea_dia_15a20',
 'f_pea_dia_9a15',
 'f_pea_dia_5a10',
 'f_pea_dia_3a5',
 'f_pea_dia_2a3',
 'f_pea_dia_1a2',
 'f_pea_dia_ate1']

# %%
dados_externos_populacao_economicamente_ativa_work = dados_externos[colunas_dados_externos_populacao_economicamente_ativa_work]
dados_externos_populacao_economicamente_ativa_work.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #### Casting

# %%
dados_externos_populacao_economicamente_ativa_work = dados_externos_populacao_economicamente_ativa_work.withColumn('cod_loja', regexp_replace('cod_loja', ',', '.').cast(IntegerType())) \
    .withColumn('f_pea_dia_20mais', regexp_replace('f_pea_dia_20mais', ',', '.').cast(IntegerType())) \
    .withColumn('f_pea_dia_15a20', regexp_replace('f_pea_dia_15a20', ',', '.').cast(IntegerType())) \
    .withColumn('f_pea_dia_9a15', regexp_replace('f_pea_dia_9a15', ',', '.').cast(IntegerType())) \
    .withColumn('f_pea_dia_5a10', regexp_replace('f_pea_dia_5a10', ',', '.').cast(IntegerType())) \
    .withColumn('f_pea_dia_3a5', regexp_replace('f_pea_dia_3a5', ',', '.').cast(IntegerType())) \
    .withColumn('f_pea_dia_2a3', regexp_replace('f_pea_dia_2a3', ',', '.').cast(IntegerType())) \
    .withColumn('f_pea_dia_1a2', regexp_replace('f_pea_dia_1a2', ',', '.').cast(IntegerType())) \
    .withColumn('f_pea_dia_ate1', regexp_replace('f_pea_dia_ate1', ',', '.').cast(IntegerType()))

# %% [markdown]
# #### Salvando

# %%
dados_externos_populacao_economicamente_ativa_work.write \
    .partitionBy(['cod_loja']) \
    .mode('overwrite') \
    .saveAsTable('dev.dados_externos_populacao_economicamente_ativa_dev')

# %%
# %sql
OPTIMIZE dev.dados_externos_populacao_economicamente_ativa_dev
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/mnt/dev/dados_externos_populacao_economicamente_ativa_dev</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 100, null, 0, 100, 100, true, 0, 0, 1679978070227, 1679978070696, 8, 0, null)</td></tr></tbody></table></div>

# %% [markdown]
# ### População que trabalha

# %% [markdown]
# #### Colunas

# %%
colunas_dados_externos_populacao_que_trabalha_work = ['cod_loja',
 'f_pop_trabalha_20mais',
 'f_pop_trabalha_15a20',
 'f_pop_trabalha_10a15',
 'f_pop_trabalha_5a10',
 'f_pop_trabalha_3a5',
 'f_pop_trabalha_2a3',
 'f_pop_trabalha_1a2',
 'f_pop_trabalha_ate1']

# %%
dados_externos_populacao_que_trabalha_work = dados_externos[colunas_dados_externos_populacao_que_trabalha_work]
dados_externos_populacao_que_trabalha_work.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #### Casting

# %%
dados_externos_populacao_que_trabalha_work = dados_externos_populacao_que_trabalha_work.withColumn('cod_loja', regexp_replace('cod_loja', ',', '.').cast(IntegerType())) \
    .withColumn('f_pop_trabalha_20mais', regexp_replace('f_pop_trabalha_20mais', ',', '.').cast(IntegerType())) \
    .withColumn('f_pop_trabalha_15a20', regexp_replace('f_pop_trabalha_15a20', ',', '.').cast(IntegerType())) \
    .withColumn('f_pop_trabalha_10a15', regexp_replace('f_pop_trabalha_10a15', ',', '.').cast(IntegerType())) \
    .withColumn('f_pop_trabalha_5a10', regexp_replace('f_pop_trabalha_5a10', ',', '.').cast(IntegerType())) \
    .withColumn('f_pop_trabalha_3a5', regexp_replace('f_pop_trabalha_3a5', ',', '.').cast(IntegerType())) \
    .withColumn('f_pop_trabalha_2a3', regexp_replace('f_pop_trabalha_2a3', ',', '.').cast(IntegerType())) \
    .withColumn('f_pop_trabalha_1a2', regexp_replace('f_pop_trabalha_1a2', ',', '.').cast(IntegerType())) \
    .withColumn('f_pop_trabalha_ate1', regexp_replace('f_pop_trabalha_ate1', ',', '.').cast(IntegerType()))

# %% [markdown]
# #### Salvando

# %%
dados_externos_populacao_que_trabalha_work.write \
    .partitionBy(['cod_loja']) \
    .mode('overwrite') \
    .saveAsTable('dev.dados_externos_populacao_que_trabalha_dev')

# %%
# %sql
OPTIMIZE dev.dados_externos_populacao_que_trabalha_dev
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/mnt/dev/dados_externos_populacao_que_trabalha_dev</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 100, null, 0, 100, 100, true, 0, 0, 1679978005619, 1679978006469, 8, 0, null)</td></tr></tbody></table></div>

# %% [markdown]
# ### Potencial de Consumo Work

# %% [markdown]
# #### Colunas

# %%
 colunas_dados_externos_potencial_consumo_work = ['cod_loja',
 'pot_cons_a',
 'pot_cons_b1',
 'pot_cons_b2',
 'pot_cons_c1',
 'pot_cons_c2',
 'pot_cons_de',
 'pot_cons_a_brinq_jogos',
 'pot_cons_b1_brinq_jogos',
 'pot_cons_b2_brinq_jogos',
 'pot_cons_c1_brinq_jogos',
 'pot_cons_c2_brinq_jogos',
 'pot_cons_de_brinq_jogos',
 'pot_cons_a_cel_acess',
 'pot_cons_b1_cel_acess',
 'pot_cons_b2_cel_acess',
 'pot_cons_c1_cel_acess',
 'pot_cons_c2_cel_acess',
 'pot_cons_de_cel_acess',
 'pot_cons_a_outros_recrea_cultura',
 'pot_cons_b1_outros_recrea_cultura',
 'pot_cons_b2_outros_recrea_cultura',
 'pot_cons_c1_outros_recrea_cultura',
 'pot_cons_c2_outros_recrea_cultura',
 'pot_cons_de_outros_recrea_cultura',
 'pot_cons_a_period_livros_rev',
 'pot_cons_b1_period_livros_rev',
 'pot_cons_b2_period_livros_rev',
 'pot_cons_c1_period_livros_rev',
 'pot_cons_c2_period_livros_rev',
 'pot_cons_de_period_livros_rev',
 'pot_cons_a_rec_esport',
 'pot_cons_b1_rec_esport',
 'pot_cons_b2_rec_esport',
 'pot_cons_c1_rec_esport',
 'pot_cons_c2_rec_esport',
 'pot_cons_de_rec_esport',
 'pot_cons_a_recrea_cultura',
 'pot_cons_b1_recrea_cultura',
 'pot_cons_b2_recrea_cultura',
 'pot_cons_c1_recrea_cultura',
 'pot_cons_c2_recrea_cultura',
 'pot_cons_de_recrea_cultura',
 'pot_cons_a_eletrod_equip',
 'pot_cons_b1_eletrod_equip',
 'pot_cons_b2_eletrod_equip',
 'pot_cons_c1_eletrod_equip',
 'pot_cons_c2_eletrod_equip',
 'pot_cons_de_eletrod_equip',
 'pot_cons_a_instru_prod_upessoal',
 'pot_cons_b1_instru_prod_upessoal',
 'pot_cons_b2_instru_prod_upessoal',
 'pot_cons_c1_instru_prod_upessoal',
 'pot_cons_c2_instru_prod_upessoal',
 'pot_cons_de_instru_prod_upessoal',
 'pot_cons_a_perfume',
 'pot_cons_b1_perfume',
 'pot_cons_b2_perfume',
 'pot_cons_c1_perfume',
 'pot_cons_c2_perfume',
 'pot_cons_de_perfume',
 'pot_cons_a_prod_cabelo',
 'pot_cons_b1_prod_cabelo',
 'pot_cons_b2_prod_cabelo',
 'pot_cons_c1_prod_cabelo',
 'pot_cons_c2_prod_cabelo',
 'pot_cons_de_prod_cabelo',
 'pot_cons_a_sabonete',
 'pot_cons_b1_sabonete',
 'pot_cons_b2_sabonete',
 'pot_cons_c1_sabonete',
 'pot_cons_c2_sabonete',
 'pot_cons_de_sabonete',
 'pot_cons_a_hig_cuidado_pess',
 'pot_cons_b1_hig_cuidado_pess',
 'pot_cons_b2_hig_cuidado_pess',
 'pot_cons_c1_hig_cuidado_pess',
 'pot_cons_c2_hig_cuidado_pess',
 'pot_cons_de_hig_cuidado_pess']

# %%
dados_externos_potencial_consumo_work = dados_externos[colunas_dados_externos_potencial_consumo_work]
dados_externos_potencial_consumo_work.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #### Casting

# %%
dados_externos_potencial_consumo_work = dados_externos_potencial_consumo_work.withColumn('cod_loja', regexp_replace('cod_loja', ',', '.').cast(IntegerType())) \
    .withColumn('pot_cons_a', regexp_replace('pot_cons_a', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b1', regexp_replace('pot_cons_b1', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b2', regexp_replace('pot_cons_b2', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c1', regexp_replace('pot_cons_c1', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c2', regexp_replace('pot_cons_c2', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_de', regexp_replace('pot_cons_de', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_a_brinq_jogos', regexp_replace('pot_cons_a_brinq_jogos', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b1_brinq_jogos', regexp_replace('pot_cons_b1_brinq_jogos', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b2_brinq_jogos', regexp_replace('pot_cons_b2_brinq_jogos', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c1_brinq_jogos', regexp_replace('pot_cons_c1_brinq_jogos', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c2_brinq_jogos', regexp_replace('pot_cons_c2_brinq_jogos', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_de_brinq_jogos', regexp_replace('pot_cons_de_brinq_jogos', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_a_cel_acess', regexp_replace('pot_cons_a_cel_acess', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b1_cel_acess', regexp_replace('pot_cons_b1_cel_acess', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b2_cel_acess', regexp_replace('pot_cons_b2_cel_acess', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c1_cel_acess', regexp_replace('pot_cons_c1_cel_acess', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c2_cel_acess', regexp_replace('pot_cons_c2_cel_acess', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_de_cel_acess', regexp_replace('pot_cons_de_cel_acess', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_a_outros_recrea_cultura', regexp_replace('pot_cons_a_outros_recrea_cultura', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b1_outros_recrea_cultura', regexp_replace('pot_cons_b1_outros_recrea_cultura', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b2_outros_recrea_cultura', regexp_replace('pot_cons_b2_outros_recrea_cultura', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c1_outros_recrea_cultura', regexp_replace('pot_cons_c1_outros_recrea_cultura', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c2_outros_recrea_cultura', regexp_replace('pot_cons_c2_outros_recrea_cultura', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_de_outros_recrea_cultura', regexp_replace('pot_cons_de_outros_recrea_cultura', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_a_period_livros_rev', regexp_replace('pot_cons_a_period_livros_rev', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b1_period_livros_rev', regexp_replace('pot_cons_b1_period_livros_rev', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b2_period_livros_rev', regexp_replace('pot_cons_b2_period_livros_rev', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c1_period_livros_rev', regexp_replace('pot_cons_c1_period_livros_rev', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c2_period_livros_rev', regexp_replace('pot_cons_c2_period_livros_rev', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_de_period_livros_rev', regexp_replace('pot_cons_de_period_livros_rev', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_a_rec_esport', regexp_replace('pot_cons_a_rec_esport', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b1_rec_esport', regexp_replace('pot_cons_b1_rec_esport', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b2_rec_esport', regexp_replace('pot_cons_b2_rec_esport', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c1_rec_esport', regexp_replace('pot_cons_c1_rec_esport', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c2_rec_esport', regexp_replace('pot_cons_c2_rec_esport', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_de_rec_esport', regexp_replace('pot_cons_de_rec_esport', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_a_recrea_cultura', regexp_replace('pot_cons_a_recrea_cultura', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b1_recrea_cultura', regexp_replace('pot_cons_b1_recrea_cultura', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b2_recrea_cultura', regexp_replace('pot_cons_b2_recrea_cultura', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c1_recrea_cultura', regexp_replace('pot_cons_c1_recrea_cultura', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c2_recrea_cultura', regexp_replace('pot_cons_c2_recrea_cultura', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_de_recrea_cultura', regexp_replace('pot_cons_de_recrea_cultura', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_a_eletrod_equip', regexp_replace('pot_cons_a_eletrod_equip', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b1_eletrod_equip', regexp_replace('pot_cons_b1_eletrod_equip', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b2_eletrod_equip', regexp_replace('pot_cons_b2_eletrod_equip', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c1_eletrod_equip', regexp_replace('pot_cons_c1_eletrod_equip', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c2_eletrod_equip', regexp_replace('pot_cons_c2_eletrod_equip', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_de_eletrod_equip', regexp_replace('pot_cons_de_eletrod_equip', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_a_instru_prod_upessoal', regexp_replace('pot_cons_a_instru_prod_upessoal', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b1_instru_prod_upessoal', regexp_replace('pot_cons_b1_instru_prod_upessoal', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b2_instru_prod_upessoal', regexp_replace('pot_cons_b2_instru_prod_upessoal', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c1_instru_prod_upessoal', regexp_replace('pot_cons_c1_instru_prod_upessoal', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c2_instru_prod_upessoal', regexp_replace('pot_cons_c2_instru_prod_upessoal', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_de_instru_prod_upessoal', regexp_replace('pot_cons_de_instru_prod_upessoal', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_a_perfume', regexp_replace('pot_cons_a_perfume', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b1_perfume', regexp_replace('pot_cons_b1_perfume', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b2_perfume', regexp_replace('pot_cons_b2_perfume', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c1_perfume', regexp_replace('pot_cons_c1_perfume', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c2_perfume', regexp_replace('pot_cons_c2_perfume', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_de_perfume', regexp_replace('pot_cons_de_perfume', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_a_prod_cabelo', regexp_replace('pot_cons_a_prod_cabelo', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b1_prod_cabelo', regexp_replace('pot_cons_b1_prod_cabelo', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b2_prod_cabelo', regexp_replace('pot_cons_b2_prod_cabelo', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c1_prod_cabelo', regexp_replace('pot_cons_c1_prod_cabelo', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c2_prod_cabelo', regexp_replace('pot_cons_c2_prod_cabelo', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_de_prod_cabelo', regexp_replace('pot_cons_de_prod_cabelo', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_a_sabonete', regexp_replace('pot_cons_a_sabonete', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b1_sabonete', regexp_replace('pot_cons_b1_sabonete', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b2_sabonete', regexp_replace('pot_cons_b2_sabonete', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c1_sabonete', regexp_replace('pot_cons_c1_sabonete', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c2_sabonete', regexp_replace('pot_cons_c2_sabonete', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_de_sabonete', regexp_replace('pot_cons_de_sabonete', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_a_hig_cuidado_pess', regexp_replace('pot_cons_a_hig_cuidado_pess', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b1_hig_cuidado_pess', regexp_replace('pot_cons_b1_hig_cuidado_pess', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_b2_hig_cuidado_pess', regexp_replace('pot_cons_b2_hig_cuidado_pess', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c1_hig_cuidado_pess', regexp_replace('pot_cons_c1_hig_cuidado_pess', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_c2_hig_cuidado_pess', regexp_replace('pot_cons_c2_hig_cuidado_pess', ',', '.').cast(DoubleType())) \
    .withColumn('pot_cons_de_hig_cuidado_pess', regexp_replace('pot_cons_de_hig_cuidado_pess', ',', '.').cast(DoubleType()))

# %% [markdown]
# #### Salvando

# %%
dados_externos_potencial_consumo_work.write \
    .partitionBy(['cod_loja']) \
    .mode('overwrite') \
    .saveAsTable('dev.dados_externos_potencial_consumo_dev')

# %%
# %sql
OPTIMIZE dev.dados_externos_potencial_consumo_dev
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/mnt/dev/dados_externos_potencial_consumo_dev</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 100, null, 0, 100, 100, true, 0, 0, 1679979085094, 1679979086006, 8, 0, null)</td></tr></tbody></table></div>
